# %%
type(-37)
# Out:
# int

# %%
13//5
# Out:
# 2

# %%
-13//5
# Out:
# -3

# %%
2**4
# Out:
# 16

# %%
"stat and data science"
# Out:
# 'stat and data science'

# %%
'stat and data science'
# Out:
# 'stat and data science'

# %%
"""stat 
and 
data """
# Out:
# 'stat \nand \ndata '

# %%
type("data science")
# Out:
# str

# %%
'"statistics" and "data"'
# Out:
# '"statistics" and "data"'

# %%
print("merhaba\nBA")
# Out:
# merhaba
# BA

# %%
print("He told us: \"Do more practice\" dedi.")
# Out:
# He told us: "Do more practice" dedi.

# %%
print("Jack\'s dessert is so delicious")
# Out:
# Jack's dessert is so delicious

# %%
print('folder:C\\user')
# Out:
# folder:C\user

# %%
"stat"+" "+"and"+' '+"data"
# Out:
# 'stat and data'

# %%
("data!"+" ")*3
# Out:
# 'data! data! data! '

# %% [markdown]
# # Variables, assignment

# %%
groupName="Stat and Data"
print(groupName)
# Out:
# Stat and Data

# %%
groupName="Stat and Data"
groupName
# Out:
# 'Stat and Data'

# %%
x, y, z=1, "b", 3*7e2
print(x,y,z)
# Out:
# 1 b 2100.0

# %%
x,y=y,x
print(x,y)
# Out:
# b 1

# %%
x
# Out:
# 'b'

# %%
v=7
v
# Out:
# 7

# %%
v+=3
v
# Out:
# 13

# %%
v-=4
v
# Out:
# 5

# %%
v
# Out:
# 5

# %%
type(z)
# Out:
# float

# %%
dir(groupName)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
X=8
X
# Out:
# 8

# %%
x==8
# Out:
# False

# %%
X==8
# Out:
# True

# %%
X!=8
# Out:
# False

# %%
X<8
# Out:
# False

# %%
X<=8
# Out:
# True

# %%
X>7 and X<=9
# Out:
# True

# %%
X<=7 or X>9
# Out:
# False

# %%
not(x==8)
# Out:
# True

# %%
x=8
x
# Out:
# 8

# %%
not(x==8)
# Out:
# False

# %%
dailyKCal =[2330,1990,2150]
dailyKCal
# Out:
# [2330, 1990, 2150]

# %%
days=["Monday","Tuesday", "Wednesday"]
days
# Out:
# ['Monday', 'Tuesday', 'Wednesday']

# %%
goodMoods=[True, True, False,False]
goodMoods
# Out:
# [True, True, False, False]

# %%
type(goodMoods)
# Out:
# list

# %%
type([2330,1990,2150])
# Out:
# list

# %%
len(days)
# Out:
# 3

# %%
dataDay1=[2330,"Mon",True]
dataDay1
# Out:
# [2330, 'Mon', True]

# %%
dataByDays=[[2330,"Mon",True], [1990,"True", True], [2150, "Wed",False]]
print(dataByDays)
len(dataByDays)
# Out:
# [[2330, 'Mon', True], [1990, 'True', True], [2150, 'Wed', False]]
# 3

# %%
emptyList=[]
emptyList
print(len(emptyList))
# Out:
# 0

# %%
dailyKCal=(2330, 1990, 2150)
dailyKCal
# Out:
# (2330, 1990, 2150)

# %%
type(dailyKCal)
# Out:
# tuple

# %%
len(dailyKCal)
# Out:
# 3

# %%
singleDayTuple=("Mon",)
singleDayTuple
# Out:
# ('Mon',)

# %%
type((1))
# Out:
# int

# %%
type((1,))
# Out:
# tuple

# %%
emptyTuble=()
print(type(emptyTuble))
print(len(emptyTuble))
emptyTuble
# Out:
# <class 'tuple'>
# 0
# ()

# %%
type(emptyTuble)
# Out:
# tuple

# %%
emptyTuble
# Out:
# ()

# %%
x,y,z=("a", True, 0)
x
# Out:
# 'a'

# %%
print(x)
# Out:
# a

# %%
americano=["espresso", "hot water"]
caffe_latte=["espresso","steamed milk"]
order_steps=2*americano+caffe_latte
order_steps
# Out:
# ['espresso', 'hot water', 'espresso', 'hot water', 'espresso', 'steamed milk']

# %%
(1)+[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 1>()
# ----> 1 (1)+[1]
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %% [markdown]
# # Access/change of a single element

# %%
day=["mon", "tue", "wed", "thur"]
day
# Out:
# ['mon', 'tue', 'wed', 'thur']

# %%
day[0]
# Out:
# 'mon'

# %%
len(day)
# Out:
# 4

# %%
day[len(day)-1]
# Out:
# 'thur'

# %%
day[-1]
# Out:
# 'thur'

# %%
day[-4]
# Out:
# 'mon'

# %%
day[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [109], in <cell line: 1>()
# ----> 1 day[7]
#
# IndexError: list index out of range

# %%
days=["Monday", "Tuesday", "Wednesday"]
days[0]="MONDAY"
days
# Out:
# ['MONDAY', 'Tuesday', 'Wednesday']

# %%
days
# Out:
# ['MONDAY', 'Tuesday', 'Wednesday']

# %%
days[0]="Mon"
days
# Out:
# ['Mon', 'Tuesday', 'Wednesday']

# %%
days=("mon", "day", "wed")
days
# Out:
# ('mon', 'day', 'wed')

# %%
days[0]="MON"
days
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 days[0]="MON"
#       2 days
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Access/change of multiple elements

# %%
days = [ "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun" ]
days
# Out:
# ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
days[2:5]
# Out:
# ['Wed', 'Thu', 'Fri']

# %%
workingDays=days[:5]
workingDays
# Out:
# ['Mon', 'Tue', 'Wed', 'Thu', 'Fri']

# %%
weekendDays=days[5:]
weekendDays
# Out:
# ['Sat', 'Sun']

# %%
copiedDays=days[:]
copiedDays
# Out:
# ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
days[1:6:2]
# Out:
# ['Tue', 'Thu', 'Sat']

# %%
days = ( "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun" )
days
# Out:
# ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun')

# %%
abc=days[5:]
abc
# Out:
# ('Sat', 'Sun')

# %%
days = [ "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun" ]
days
# Out:
# ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
days[1:3]=["TUE", "WED"]
days
# Out:
# ['Mon', 'TUE', 'WED', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
days[2:3]=["TUESDAY", "MOON-eee-night!!", "WEDNESDAY"]
days
# Out:
# ['Mon',
#  'TUE',
#  'TUESDAY',
#  'MOON-eee-night!!',
#  'WEDNESDAY',
#  'Thu',
#  'Fri',
#  'Sat',
#  'Sun']

# %%
days = [ "Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun" ]
days
days[2:3] = [ "TUESDAY", "moon-eclipse-night!!!", "WEDNESDAY" ]
days
# Out:
# ['Mon',
#  'Tue',
#  'TUESDAY',
#  'moon-eclipse-night!!!',
#  'WEDNESDAY',
#  'Thu',
#  'Fri',
#  'Sat',
#  'Sun']

# %% [markdown]
# # Shallow and Deeper Copying

# %%
v=[1,2,3]
w=v
v[0]=100
v
# Out:
# [100, 2, 3]

# %%
w
# Out:
# [100, 2, 3]

# %%
v=[1,2,3]
w=v.copy()
v[0]=100
v
# Out:
# [100, 2, 3]

# %%
w #Now, the change of v has not affected
# Out:
# [1, 2, 3]

# %% [markdown]
# # List Coprehensions

# %% [markdown]
# Let's introduce a very powerful mechanisms allowing to perform operations on all elements of lists, tuples (or other iterable objects).
#
# The following list comprehension code [x**2 for x in someNums]:
#
# outputs a list: it is a list comprehension because of surrounding brackets [ ... ]
# iterates through someNums (an object which can be iterated over)
# in each iteration x is set to a subsequent element value (for x in)
# the result of expression x**2 is stored to the output list

# %%
someNums=[1,-1,2,3,4]
[(x,x**2) for x in someNums]
# Out:
# [(1, 1), (-1, 1), (2, 4), (3, 9), (4, 16)]

# %%
someNums=[1,-1,2,3,4]
[x for x in someNums if x<0]
# Out:
# [-1]

# %%
someNums = [ 1, -2, 3, -4, 5 ]        # an iterable object
[x for x in someNums if x<0]
# Out:
# [-2, -4]

# %%
x="I am the outside x"
someNums=[1,-2,3,-4,5]
[x for x in someNums if x<0]
x
# Out:
# 'I am the outside x'

# %%
nums=(1,2,3)
nums[1]=22 #doesn't work with tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [162], in <cell line: 2>()
#       1 nums=(1,2,3)
# ----> 2 nums[1]=22
#
# TypeError: 'tuple' object does not support item assignment

# %%
txt = "Statistics"
#txt[0] = "s"              # what's wrong here? doesn't work in strings, " "

# %%
v = [ 1, 2, 3 ]
a = v
v = [ 4, 5, 6 ]
a
# Out:
# [1, 2, 3]

# %%
v = [ 1, 2, 3 ]
b = v
v[:] = [ 4, 5, 6 ] #changed it
b
# Out:
# [4, 5, 6]

# %%
v = [ 1, 2, 3 ]
b = v
v[:] = [ 4, 5, 6,7 ] #changed it
b
# Out:
# [4, 5, 6, 7]

# %%
v = [ 5, 2, 1, 4, 3 ]
v.sort()
v
v.sort(reverse=True)
v
# Out:
# [5, 4, 3, 2, 1]

# %%
v = [ 5, 2, 1, 4, 3 ]
w=v
v=sorted(w)
v
w
# Out:
# [5, 2, 1, 4, 3]

# %%
v = [ 5, 2, 1, 4, 3 ]
v.reverse()
v
# Out:
# [3, 4, 1, 2, 5]

# %%
v = [ 5, 2, 1, 4, 3 ]
w=v
v=list(reversed(w))
print(v)
print(w)
# Out:
# [3, 4, 1, 2, 5]
# [5, 2, 1, 4, 3]

# %%
v = [ 5, 2, 1, 4, 3 ]
w=v
v=w[::-1]
print(v)
print(w)
# Out:
# [3, 4, 1, 2, 5]
# [5, 2, 1, 4, 3]

# %% [markdown]
# Deleting and removing

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
del v[2]
v
# Out:
# ['eeeee', 'bb', 'dddd', 'ccc', 'bb']

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v.remove("bb")
v
# Out:
# ['eeeee', 'a', 'dddd', 'ccc', 'bb']

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v=[x for x in v if x !="b"]
v
# Out:
# ['eeeee', 'bb', 'a', 'dddd', 'ccc', 'bb']

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v.insert(2, "F")
v
# Out:
# ['eeeee', 'bb', 'F', 'a', 'dddd', 'ccc', 'bb']

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v[2:2]=w
v
# Out:
# ['eeeee', 'bb', 5, 2, 1, 4, 3, 'a', 'dddd', 'ccc', 'bb']

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v[:]=w
v
# Out:
# [5, 2, 1, 4, 3]

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v.append("F")
v
# Out:
# ['eeeee', 'bb', 'a', 'dddd', 'ccc', 'bb', 'F']

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v.extend(w)
v
# Out:
# ['eeeee', 'bb', 'a', 'dddd', 'ccc', 'bb', 5, 2, 1, 4, 3]

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v+=w
v
# Out:
# ['eeeee', 'bb', 'a', 'dddd', 'ccc', 'bb', 5, 2, 1, 4, 3]

# %%
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v.append(w)
v
# Out:
# ['eeeee', 'bb', 'a', 'dddd', 'ccc', 'bb', [5, 2, 1, 4, 3]]

# %%
v = [ "ababab", "baaab", "bbbaa", "aabba", "aaaab", "abbaa", "aabbb", "abaaa", "aaaaa", "bbbab", "bbbqb", "aaaqb", "bbbbq" ]
w = "bbbab"
result=w in v
print(result)


# How to programmatically find whether the value of w is *in* the iterable list v?
# The result should be True or False
# Out:
# True

# %%
v = [ "ababab", "baaab", "bbbaa", "aabba", "aaaab", "abbaa", "aabbb", "abaaa", "aaaaa", "bbbab", "bbbqb", "aaaqb", "bbbbq" ]
w = "abaab"
result=w not in v
print(result)


# How to programmatically find whether the value of w is *not in* the iterable list v?
# The result should be True or False
# Out:
# True

# %%
lst = [1,2,3,"x","y","z"]
tuple( lst )
# Out:
# (1, 2, 3, 'x', 'y', 'z')

# %%
tpl = (1,2,3,"x","y","z")
list( tpl )
# Out:
# [1, 2, 3, 'x', 'y', 'z']

# %%
tuple("Statistics")
# Out:
# ('S', 't', 'a', 't', 'i', 's', 't', 'i', 'c', 's')

# %%
list('Data Science')
# Out:
# ['D', 'a', 't', 'a', ' ', 'S', 'c', 'i', 'e', 'n', 'c', 'e']

# %%
xs = [ 0, 1, 2, 3, 4, 5 ]

# %%
toRemove = "bb"
v = [ "eeeee", "bb", "a", "dddd", "ccc", "bb" ]
v
# Out:
# ['eeeee', 'bb', 'a', 'dddd', 'ccc', 'bb']

# %%
xs = [ 0, 1, 2, 3, 4, 5 ]
xs=range(6)
ys=[x**2+x+1 for x in xs]
ys
# ys = [ ... ]            # write a comprehension to transform 
                          #   elements of xs according to formula:
                          #   y = x^2 + x + 1
# Out:
# [1, 3, 7, 13, 21, 31]
